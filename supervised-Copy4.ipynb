# %%
import torch
import pickle
import time
import numpy as np
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import gridspec
import matplotlib.patches as mpatches
from skimage import exposure
from torchvision import datasets
import torchvision.transforms as transforms
from torchvision import utils

# %%
is_cuda = torch.cuda.is_available()

# %%
seed = 10

n_classes = 10
#dimension of z or latent representation
z_dimension = 3
#dimension of X or data
X_dimension = 784
#dimension of label of data
y_dimension = 10

TRAIN_BATCH_SIZE = 100
VALID_BATCH_SIZE = 10000
EPOCHS = 250
N = 1000
TINY_ERROR = 1e-15
DATA_PATH = "/floyd/input/skripsi_datasets_2/"
cuda = torch.device('cuda')

training_reconstruction_loss = []
training_generator_loss = []
training_discriminator_loss = []
training_generator_sample = []

# %%
train_loader = torch.utils.data.DataLoader(
    datasets.MNIST(
        "../../home/Data/mnist",
        train=True,
        download=True,
        transform=transforms.Compose(
            [transforms.Resize(28), transforms.ToTensor()]
        ),
    ),
    batch_size=TRAIN_BATCH_SIZE,
    shuffle=True,
)

valid_loader = torch.utils.data.DataLoader(
    datasets.MNIST(
        "../../home/Data/mnist",
        train=False,
        download=True,
        transform=transforms.Compose(
            [transforms.Resize(28), transforms.ToTensor()]
        ),
    ),
    batch_size=VALID_BATCH_SIZE,
    shuffle=True,
)


class Convolutional_Net(nn.Module):
    def __init__(self):
        super(Convolutional_Net, self).__init__()
        self.convolutional1 = nn.Conv2d(1, 20, 5, 1)
        self.convolutional2 = nn.Conv2d(20, 50, 5 , 1)
        self.linear1 = nn.Linear(4*4*50, 500)
        self.linear2 = nn.Linear(500, 10)
    
    def forward(self, x):
        x = F.relu(self.convolutional1(x))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.convolutional2(x))
        x = F.max_pool2d(x, 2, 2)
        x = x.view(-1, 4*4*50)
        x = F.relu(self.linear1(x))
        x = self.linear2(x)
        return F.log_softmax(x, dim=1)

with torch.no_grad():
    classifier = Convolutional_Net()
    classifier.load_state_dict(torch.load("classification.pt"))
    classifier.cuda(cuda)
    classifier.eval()

# %%
class Encoder_net(nn.Module):
    def __init__(self):
        super(Encoder_net, self).__init__()
        self.layer1 = nn.Linear(X_dimension, N)
        self.layer2 = nn.Linear(N, N)
        self.layer3 = nn.Linear(N, z_dimension)

    def forward(self, x):
        x = F.dropout(self.layer1(x), p=0.5, training=self.training)
        x = F.relu(x)
        x = F.dropout(self.layer2(x), p=0.5, training=self.training)
        x = F.relu(x)
        x = self.layer3(x)

        return x


# Decoder
class Decoder_net(nn.Module):
    def __init__(self):
        super(Decoder_net, self).__init__()
        self.layer1 = nn.Linear(z_dimension + n_classes, N)
        self.layer2 = nn.Linear(N, N)
        self.layer3 = nn.Linear(N, X_dimension)

    def forward(self, x):
        x = self.layer1(x)
        x = F.dropout(x, p=0.5, training=self.training)
        x = F.relu(x)
        x = self.layer2(x)
        x = F.dropout(x, p=0.5, training=self.training)
        s = F.relu(x)
        x = self.layer3(x)
        return F.sigmoid(x)

class Discriminator_net_gauss(nn.Module):
    def __init__(self):
        super(Discriminator_net_gauss, self).__init__()
        self.layer1 = nn.Linear(z_dimension, N)
        self.layer2 = nn.Linear(N, N)
        self.layer3 = nn.Linear(N, 1)

    def forward(self, x):
        x = F.dropout(self.layer1(x), p=0.5, training=self.training)
        x = F.relu(x)
        x = F.dropout(self.layer2(x), p=0.5, training=self.training)
        x = F.relu(x)

        return self.layer3(x)

    
def free_params(module: nn.Module):
    for p in module.parameters():
        p.requires_grad = True

def frozen_params(module: nn.Module):
    for p in module.parameters():
        p.requires_grad = False

# %%
Tensor = torch.cuda.FloatTensor
def train_one_epoch(decoder, encoder, discriminator_gauss, decoder_optimizer, encoder_optimizer, generator_optimizer, discriminator_optimizer, data_loader):
    #'''
    encoder.train()
    decoder.train()
    discriminator_gauss.train()

    for X, target in data_loader:
        #X = X * 0.3081 + 0.1307
        X.resize_(TRAIN_BATCH_SIZE, X_dimension)
        X, target = Variable(X), Variable(target)
        if cuda:
            X, target = X.cuda(cuda), target.cuda(cuda)

        # Init gradients
        decoder.zero_grad()
        encoder.zero_grad()
        discriminator_gauss.zero_grad()


        z_gauss = encoder(X)
        
        category = np.array(target.data.tolist())
        category = np.eye(n_classes)[category].astype('float32')
        category = torch.from_numpy(category)
        z_category = Variable(category)
        
        if cuda:
            z_category = z_category.cuda(cuda)

        z_sample = torch.cat((z_category, z_gauss), 1)

        X_sample = decoder(z_sample)
        compared_with_original = X.resize(TRAIN_BATCH_SIZE, X_dimension)
        mse_loss = torch.nn.MSELoss()
        reconstruction_loss = 0.1 * mse_loss(X_sample + TINY_ERROR, compared_with_original + TINY_ERROR)
        
        reconstruction_loss.backward()
        decoder_optimizer.step()
        encoder_optimizer.step()

        decoder.zero_grad()
        encoder.zero_grad()
        discriminator_gauss.zero_grad()

        # Discriminator
        encoder.eval()
        z_real_gauss = Variable(torch.randn(TRAIN_BATCH_SIZE, z_dimension) * 5.)
        if cuda:
            z_real_gauss = z_real_gauss.cuda(cuda)

        z_fake_gauss = encoder(X)

        discriminator_real_gauss = discriminator_gauss(z_real_gauss)
        discriminator_fake_gauss = discriminator_gauss(z_fake_gauss)

        discriminator_loss = 0.5 * (torch.mean((discriminator_real_gauss + TINY_ERROR - 1)**2) + torch.mean((discriminator_fake_gauss + TINY_ERROR)**2))

        discriminator_loss.backward()
        discriminator_optimizer.step()

        decoder.zero_grad()
        encoder.zero_grad()
        discriminator_gauss.zero_grad()

        # Generator
        encoder = encoder.train()
        z_fake_gauss = encoder(X)

        generator_fake_gauss = discriminator_gauss(z_fake_gauss)
        generator_loss = 0.5 * torch.mean((generator_fake_gauss + TINY_ERROR - 1)**2)

        generator_loss.backward()
        generator_optimizer.step()

        decoder.zero_grad()
        encoder.zero_grad()
        discriminator_gauss.zero_grad()
    #'''
    '''
    encoder.train()
    decoder.train()
    discriminator_gauss.train()
    
    reconstruction_loss = None
    real_loss = None
    fake_loss = None
    generator_loss = None
    #reconstruction_loss = None
    
    for X, target in train_loader:
        encoder.zero_grad()
        decoder.zero_grad()
        discriminator_gauss.zero_grad()
        
        valid = Variable(Tensor(TRAIN_BATCH_SIZE, 1).fill_(0.9), requires_grad=False)
        fake = Variable(Tensor(TRAIN_BATCH_SIZE, 1).fill_(0.1), requires_grad=False)
        
        X = X.resize(TRAIN_BATCH_SIZE, 784)
        X, target = Variable(X), Variable(target)
        
        if is_cuda:
            X, target = X.cuda(cuda), target.cuda(cuda)
              
        
        mse_loss = torch.nn.MSELoss()
        
        frozen_params(decoder)
        frozen_params(encoder)
        free_params(discriminator_gauss)
        
        z_real = torch.randn(TRAIN_BATCH_SIZE, z_dimension) * 1.0
        z_real = z_real.cuda(cuda)
        real_value = discriminator_gauss(z_real)
        
        z_fake = encoder(X)
                
        fake_value = discriminator_gauss(z_fake)
        
        real_loss = 0.01 * mse_loss(real_value + TINY_ERROR, valid)
        fake_loss = 0.01 * mse_loss(fake_value + TINY_ERROR, fake)
        
        real_loss.backward()
        fake_loss.backward()
        
        discriminator_optimizer.step()
        
        free_params(decoder)
        free_params(encoder)
        frozen_params(discriminator_gauss)
        
        z = encoder(X)
        
        
        category = np.array(target.data.tolist())
        category = np.eye(n_classes)[category].astype('float32')
        category = torch.from_numpy(category)
        z_category = Variable(category)
        
        if cuda:
            z_category = z_category.cuda(cuda)

        #print(z_category.size())
        #z_category = z_category.resize(TRAIN_BATCH_SIZE, 1, n_classes)
        z_with_label = torch.cat((z_category, z), 1)
        
        
        
        x_hat = decoder(z_with_label)
        
        z_2 = encoder(Variable(X.data))
        z_2_dis = discriminator_gauss(z_2)
        
        x_hat_resize = x_hat.view(-1, 784)
        X_resize = X.view(-1, 784)
        
        reconstruction_loss = 0.25 * mse_loss(x_hat_resize + TINY_ERROR, X_resize)
        generator_loss = 0.01 * mse_loss(z_2_dis + TINY_ERROR, valid)
        
        reconstruction_loss.backward()
        generator_loss.backward()
        
        encoder_optimizer.step()
        decoder_optimizer.step()
    '''
    return discriminator_loss, generator_loss, reconstruction_loss
    #return real_loss + fake_loss, generator_loss, reconstruction_loss

# %%
def train_model(train_loader, valid_loader):
    torch.manual_seed(10)

    if cuda:
        encoder = Encoder_net().cuda(cuda)
        decoder = Decoder_net().cuda(cuda)
        discriminator_gauss = Discriminator_net_gauss().cuda(cuda)
    else:
        encoder = Encoder_net()
        decoder = Decoder_net()
        discriminator_gauss = Discriminator_net_gauss()

    #learning rates for optimization
    learning_rate_1 = 0.0002
    learning_rate_2 = 0.0002

    #optimization for decoder and encoder
    decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate_1)
    encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate_1)

    generator_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate_1)
    discriminator_optimizer = optim.Adam(discriminator_gauss.parameters(), lr=learning_rate_1)

    for epoch in range(EPOCHS):
        start_time = time.time()
        discriminator_loss, generator_loss, reconstruction_loss = train_one_epoch(decoder, encoder, discriminator_gauss, 
                                                                              decoder_optimizer, encoder_optimizer, generator_optimizer, 
                                                                              discriminator_optimizer, train_loader)
        
        epoch_time = time.time() - start_time
        if epoch % 1 == 0:
            training_reconstruction_loss.append(reconstruction_loss)
            training_generator_loss.append(generator_loss)
            training_discriminator_loss.append(discriminator_loss)
            print('Epoch-{}, Time-{:.2}, Discriminator_loss-{:.4}, Generator_loss-{:.4}, reconstruction_loss-{:.4}'.format(epoch, epoch_time, discriminator_loss.item(), generator_loss.item(), reconstruction_loss.item()))
    
        
        if epoch % 1 == 0:
            with torch.no_grad():
                encoder = encoder.eval()
                decoder = decoder.eval()
                discriminator_gauss = discriminator_gauss.eval()

                X_test = None
                y_test = None

                for X, target in valid_loader:
                    X_test = X
                    y_test = target
                    break

                if is_cuda:
                    X_test = X_test.cuda(cuda)

                X_test = X_test.resize(VALID_BATCH_SIZE, X_dimension) 

                list_y_test = []
                for item in y_test:
                    list_y_test.append(item.item())


                encoded_X_test = encoder(X_test)
                training_generator_sample.append(encoded_X_test)
                target_list = list_y_test

                '''
                figure = plt.figure()
                set_classes = set(target_list)
                color_map = plt.cm.rainbow(np.linspace(0, 1, len(set_classes)))
                axis = plt.subplot(111, aspect='equal')
                box = axis.get_position()
                axis.set_position([box.x0, box.y0, box.width * 0.8, box.height])
                handles = [mpatches.Circle((0, 0), label=class_, color=color_map[i]) for i, class_ in enumerate(set_classes)]
                axis.legend(handles=handles, shadow=True, bbox_to_anchor=(1.05, 0.45), fancybox=True, loc='center left')
                kwargs = {'alpha': 0.8, 'c': [color_map[i] for i in target_list]}
                encoded_X_test_cpu = encoded_X_test.cpu()
                plt.scatter(encoded_X_test_cpu[:, 0].detach().numpy(), encoded_X_test_cpu[:, 1].detach().numpy(), s = 2, **kwargs)
                axis.set_xlim([-20, 20])
                axis.set_ylim([-20, 20])

                plt.savefig('2_latent_space_supervised_aae_least/epoch_%d.png' % epoch)
                plt.close('all')
                '''

                n_digits = 20
                #decoded_X_test = decoder(encoder(X_test[:n_digits]))

                category_test = np.array(y_test.numpy().data.tolist())
                category_test = np.eye(n_classes)[category_test].astype('float32')
                category_test = torch.from_numpy(category_test)
                
                z_category_test = Variable(category_test[:n_digits])
                encoded_X_test = encoder(X_test[:n_digits])

                if is_cuda:
                    z_category_test = z_category_test.cuda(cuda)

                encoded_X_test = torch.cat((z_category_test, encoded_X_test), 1)
                decoded_X_test = decoder(encoded_X_test)

                resized_decoded_X_test = decoded_X_test.resize(n_digits, 1, 28, 28)
                resized_decoded_X_test = resized_decoded_X_test.cuda(cuda)
                label_decoded = classifier(resized_decoded_X_test)
                label_decoded = label_decoded.argmax(dim=1, keepdim=True)
                label_decoded = torch.flatten(label_decoded)

                original_X = X_test[:n_digits]
                resized_original_X = original_X.resize(n_digits, 1, 28, 28)
                resized_original_X = resized_original_X.cuda(cuda)
                target_original_X = classifier(resized_original_X)
                target_original_X = target_original_X.argmax(dim=1, keepdim=True)
                target_original_X = torch.flatten(target_original_X)

                decoded_label_cpu = label_decoded.cpu().detach().numpy()
                decoded_target_original_X = target_original_X.cpu().detach().numpy()
                decoded_X_test_cpu = decoded_X_test.cpu()
                decoded_X_test_cpu = np.reshape(decoded_X_test_cpu.detach().numpy(), [-1, 28, 28]) * 255
                figure = plt.figure(figsize=(20, 4))

                for i in range (n_digits):
                    axis = plt.subplot(2, n_digits, i + 1)
                    axis.set_title(str(decoded_target_original_X[i]))
                    X_test_cpu = X_test.cpu()
                    plt.imshow(X_test_cpu[i].reshape(28, 28).detach().numpy())
                    plt.gray()
                    axis.get_xaxis().set_visible(False)
                    axis.get_yaxis().set_visible(False)

                    axis = plt.subplot(2, n_digits, i + 1 + n_digits)
                    axis.set_title(str(decoded_label_cpu[i]))
                    plt.imshow(decoded_X_test_cpu[i])
                    plt.gray()
                    axis.get_xaxis().set_visible(False)
                    axis.get_yaxis().set_visible(False)

                plt.savefig('7_reconstruction_supervised_aae_least/recon_%d.png' % epoch)
                plt.close('all')
                
                
                z = torch.randn(20, z_dimension) * 5
                z = z.float().cuda(cuda)

                target = torch.randint(10, (20, 1))
                target = target.flatten()

                one_hot_target = torch.zeros(20, 10)
                one_hot_target[torch.arange(20), target] = 1
                one_hot_target = one_hot_target.cuda(cuda)

                z_target = torch.cat([one_hot_target, z], dim=1)
                z_target = z_target.cuda(cuda)

                recon_z = decoder(z_target)
                recon_z = recon_z.resize(20, 1, 28, 28)
                
                recon = recon_z.cpu()
                recon = np.reshape(recon.detach().numpy(), [-1, 28, 28]) * 255
                
                figure = plt.figure(figsize=(20, 4))

                for i in range (20):
                    axis = plt.subplot(2, n_digits, i + 1)
                    plt.imshow(recon[i].reshape(28, 28))
                    plt.gray()
                    axis.get_xaxis().set_visible(False)
                    axis.get_yaxis().set_visible(False)
                
                plt.savefig('7_sampling_supervised_aae_least/epoch_%d.png' % epoch)
                plt.close()
                

                '''
                z_sampling = [np.linspace(-5, 5, 10) for i in range (10)]

                n_x, n_y = 10, 10
                random_input = np.random.randn(10, z_dimension)
                sample_y = np.identity(10)
                plt.subplot()
                grid_spec = gridspec.GridSpec(n_x, n_y, hspace=0.05, wspace=0.05)
                i = 0
                for r in random_input:
                    for t in sample_y:
                        r = np.reshape(r, (1, z_dimension))
                        t = np.reshape(t, (1, n_classes))
                        input_decoder = np.concatenate((t, r), 1)
                        input_decoder = input_decoder.astype('float32')
                        input_decoder = torch.from_numpy(input_decoder).float()
                        input_decoder = input_decoder.cuda(cuda)

                        decoded_X = decoder(input_decoder)
                        decoded_X_cpu = decoded_X.cpu().detach().numpy()

                        axis = plt.subplot(grid_spec[i])
                        i += 1
                        image = np.array(decoded_X_cpu.tolist()).reshape(28, 28)
                        axis.imshow(image, cmap='gray')
                        axis.set_xticks([])
                        axis.set_yticks([])
                        axis.set_aspect('auto')

                plt.savefig('3_sampling_supervised_aae_least/epoch_%d.png' % epoch)
                plt.close()
                '''
                
                encoder = encoder.train()
                decoder = decoder.train()
                discriminator_gauss = discriminator_gauss.train()

    return encoder, decoder

# %%
trained_encoder, trained_decoder = train_model(train_loader, valid_loader)
# Out:
# /opt/conda/lib/python3.6/site-packages/torch/nn/functional.py:1625: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# /opt/conda/lib/python3.6/site-packages/torch/tensor.py:357: UserWarning: non-inplace resize is deprecated
#   warnings.warn("non-inplace resize is deprecated")
# Epoch-0, Time-1.2e+01, Discriminator_loss-0.2687, Generator_loss-0.1662, reconstruction_loss-0.004478
# Epoch-1, Time-1.2e+01, Discriminator_loss-0.2512, Generator_loss-0.1488, reconstruction_loss-0.004101
# Epoch-2, Time-1.2e+01, Discriminator_loss-0.263, Generator_loss-0.1319, reconstruction_loss-0.004199
# Epoch-3, Time-1.3e+01, Discriminator_loss-0.26, Generator_loss-0.1401, reconstruction_loss-0.003841
# Epoch-4, Time-1.2e+01, Discriminator_loss-0.2595, Generator_loss-0.131, reconstruction_loss-0.004044
# Epoch-5, Time-1.2e+01, Discriminator_loss-0.2536, Generator_loss-0.1305, reconstruction_loss-0.003303
# Epoch-6, Time-1.2e+01, Discriminator_loss-0.2505, Generator_loss-0.1247, reconstruction_loss-0.003863
# Epoch-7, Time-1.2e+01, Discriminator_loss-0.2484, Generator_loss-0.1291, reconstruction_loss-0.003544
# Epoch-8, Time-1.2e+01, Discriminator_loss-0.2511, Generator_loss-0.1266, reconstruction_loss-0.003668
# Epoch-9, Time-1.2e+01, Discriminator_loss-0.2499, Generator_loss-0.1244, reconstruction_loss-0.003605
# Epoch-10, Time-1.4e+01, Discriminator_loss-0.2505, Generator_loss-0.126, reconstruction_loss-0.003566
# Epoch-11, Time-1.2e+01, Discriminator_loss-0.2497, Generator_loss-0.1267, reconstruction_loss-0.003436
# Epoch-12, Time-1.1e+01, Discriminator_loss-0.25, Generator_loss-0.1264, reconstruction_loss-0.003434
# Epoch-13, Time-1.2e+01, Discriminator_loss-0.2493, Generator_loss-0.126, reconstruction_loss-0.003255
# Epoch-14, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.1266, reconstruction_loss-0.003449
# Epoch-15, Time-1.2e+01, Discriminator_loss-0.2507, Generator_loss-0.1245, reconstruction_loss-0.003729
# Epoch-16, Time-1.2e+01, Discriminator_loss-0.2512, Generator_loss-0.125, reconstruction_loss-0.00353
# Epoch-17, Time-1.2e+01, Discriminator_loss-0.2501, Generator_loss-0.1254, reconstruction_loss-0.003086
# Epoch-18, Time-1.2e+01, Discriminator_loss-0.2507, Generator_loss-0.1258, reconstruction_loss-0.003335
# Epoch-19, Time-1.2e+01, Discriminator_loss-0.2503, Generator_loss-0.1244, reconstruction_loss-0.003516
# Epoch-20, Time-1.2e+01, Discriminator_loss-0.2502, Generator_loss-0.1251, reconstruction_loss-0.003442
# Epoch-21, Time-1.2e+01, Discriminator_loss-0.2505, Generator_loss-0.1252, reconstruction_loss-0.003382
# Epoch-22, Time-1.2e+01, Discriminator_loss-0.2503, Generator_loss-0.1252, reconstruction_loss-0.003141
# Epoch-23, Time-1.2e+01, Discriminator_loss-0.2508, Generator_loss-0.1252, reconstruction_loss-0.00346
# Epoch-24, Time-1.2e+01, Discriminator_loss-0.2501, Generator_loss-0.1255, reconstruction_loss-0.003454
# Epoch-25, Time-1.2e+01, Discriminator_loss-0.2503, Generator_loss-0.1249, reconstruction_loss-0.003017
# Epoch-26, Time-1.2e+01, Discriminator_loss-0.2524, Generator_loss-0.1243, reconstruction_loss-0.003277
# Epoch-27, Time-1.1e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003423
# Epoch-28, Time-1.1e+01, Discriminator_loss-0.2501, Generator_loss-0.1254, reconstruction_loss-0.003454
# Epoch-29, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.1256, reconstruction_loss-0.003345
# Epoch-30, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.1251, reconstruction_loss-0.003243
# Epoch-31, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.1253, reconstruction_loss-0.003372
# Epoch-32, Time-1.2e+01, Discriminator_loss-0.2503, Generator_loss-0.1246, reconstruction_loss-0.003312
# Epoch-33, Time-1.1e+01, Discriminator_loss-0.2501, Generator_loss-0.1251, reconstruction_loss-0.003263
# Epoch-34, Time-1.1e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003234
# Epoch-35, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003246
# Epoch-36, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003048
# Epoch-37, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003274
# Epoch-38, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003526
# Epoch-39, Time-1.2e+01, Discriminator_loss-0.2501, Generator_loss-0.125, reconstruction_loss-0.003266
# Epoch-40, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003112
# Epoch-41, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.002983
# Epoch-42, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.1252, reconstruction_loss-0.003298
# Epoch-43, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.1251, reconstruction_loss-0.003441
# Epoch-44, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.1253, reconstruction_loss-0.003226
# Epoch-45, Time-1.3e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003185
# Epoch-46, Time-1.3e+01, Discriminator_loss-0.2498, Generator_loss-0.1251, reconstruction_loss-0.003053
# Epoch-47, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.1249, reconstruction_loss-0.003216
# Epoch-48, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003181
# Epoch-49, Time-1.3e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003219
# Epoch-50, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003233
# Epoch-51, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003036
# Epoch-52, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003306
# Epoch-53, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.1249, reconstruction_loss-0.003294
# Epoch-54, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003428
# Epoch-55, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003257
# Epoch-56, Time-1.2e+01, Discriminator_loss-0.2499, Generator_loss-0.1249, reconstruction_loss-0.003223
# Epoch-57, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003198
# Epoch-58, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003319
# Epoch-59, Time-1.3e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003133
# Epoch-60, Time-1.3e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003077
# Epoch-61, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003151
# Epoch-62, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003101
# Epoch-63, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.002863
# Epoch-64, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.1249, reconstruction_loss-0.003159
# Epoch-65, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003165
# Epoch-66, Time-1.1e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003287
# Epoch-67, Time-1.2e+01, Discriminator_loss-0.2499, Generator_loss-0.1252, reconstruction_loss-0.003361
# Epoch-68, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003272
# Epoch-69, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003021
# Epoch-70, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003137
# Epoch-71, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003312
# Epoch-72, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003165
# Epoch-73, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003323
# Epoch-74, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.002781
# Epoch-75, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.00311
# Epoch-76, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003086
# Epoch-77, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003312
# Epoch-78, Time-1.3e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003201
# Epoch-79, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003376
# Epoch-80, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003309
# Epoch-81, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003149
# Epoch-82, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003004
# Epoch-83, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003049
# Epoch-84, Time-1.1e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003255
# Epoch-85, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003231
# Epoch-86, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.00328
# Epoch-87, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003109
# Epoch-88, Time-1.1e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003268
# Epoch-89, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003068
# Epoch-90, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003266
# Epoch-91, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.1249, reconstruction_loss-0.003229
# Epoch-92, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003435
# Epoch-93, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003342
# Epoch-94, Time-1.2e+01, Discriminator_loss-0.2501, Generator_loss-0.125, reconstruction_loss-0.003314
# Epoch-95, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003187
# Epoch-96, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003337
# Epoch-97, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003372
# Epoch-98, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003235
# Epoch-99, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.002872
# Epoch-100, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003148
# Epoch-101, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.1251, reconstruction_loss-0.003164
# Epoch-102, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.00316
# Epoch-103, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003209
# Epoch-104, Time-1.2e+01, Discriminator_loss-0.2504, Generator_loss-0.1245, reconstruction_loss-0.003337
# Epoch-105, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.1251, reconstruction_loss-0.003378
# Epoch-106, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.002841
# Epoch-107, Time-1.1e+01, Discriminator_loss-0.25, Generator_loss-0.1251, reconstruction_loss-0.003272
# Epoch-108, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.00323
# Epoch-109, Time-1.3e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003059
# Epoch-110, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.002789
# Epoch-111, Time-1.2e+01, Discriminator_loss-0.2502, Generator_loss-0.1249, reconstruction_loss-0.003146
# Epoch-112, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003265
# Epoch-113, Time-1.1e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.002938
# Epoch-114, Time-1.1e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003291
# Epoch-115, Time-1.1e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003104
# Epoch-116, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.1251, reconstruction_loss-0.003297
# Epoch-117, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003368
# Epoch-118, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.002975
# Epoch-119, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.002998
# Epoch-120, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003135
# Epoch-121, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.002978
# Epoch-122, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003155
# Epoch-123, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.002986
# Epoch-124, Time-1.1e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003069
# Epoch-125, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003162
# Epoch-126, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003199
# Epoch-127, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.1251, reconstruction_loss-0.003054
# Epoch-128, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003128
# Epoch-129, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.002949
# Epoch-130, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003105
# Epoch-131, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.1251, reconstruction_loss-0.002931
# Epoch-132, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.1251, reconstruction_loss-0.003005
# Epoch-133, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.00297
# Epoch-134, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.1249, reconstruction_loss-0.003086
# Epoch-135, Time-1.2e+01, Discriminator_loss-0.2505, Generator_loss-0.125, reconstruction_loss-0.002981
# Epoch-136, Time-1.1e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003083
# Epoch-137, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003005
# Epoch-138, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003024
# Epoch-139, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003013
# Epoch-140, Time-1.2e+01, Discriminator_loss-0.2502, Generator_loss-0.125, reconstruction_loss-0.003057
# Epoch-141, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.1251, reconstruction_loss-0.003082
# Epoch-142, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003065
# Epoch-143, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003035
# Epoch-144, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.002918
# Epoch-145, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003411
# Epoch-146, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003084
# Epoch-147, Time-1.3e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.002974
# Epoch-148, Time-1.2e+01, Discriminator_loss-0.2499, Generator_loss-0.1248, reconstruction_loss-0.003194
# Epoch-149, Time-1.2e+01, Discriminator_loss-0.2498, Generator_loss-0.1248, reconstruction_loss-0.003069
# Epoch-150, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.1251, reconstruction_loss-0.003087
# Epoch-151, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003084
# Epoch-152, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.00326
# Epoch-153, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003078
# Epoch-154, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.002789
# Epoch-155, Time-1.2e+01, Discriminator_loss-0.2501, Generator_loss-0.125, reconstruction_loss-0.0032
# Epoch-156, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003213
# Epoch-157, Time-1.3e+01, Discriminator_loss-0.2501, Generator_loss-0.1251, reconstruction_loss-0.002942
# Epoch-158, Time-1.2e+01, Discriminator_loss-0.2499, Generator_loss-0.125, reconstruction_loss-0.003088
# Epoch-159, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003232
# Epoch-160, Time-1.1e+01, Discriminator_loss-0.2501, Generator_loss-0.1246, reconstruction_loss-0.003499
# Epoch-161, Time-1.1e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003123
# Epoch-162, Time-1.1e+01, Discriminator_loss-0.251, Generator_loss-0.1173, reconstruction_loss-0.003679
# Epoch-163, Time-1.1e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.002994
# Epoch-164, Time-1.1e+01, Discriminator_loss-0.2499, Generator_loss-0.1251, reconstruction_loss-0.002975
# Epoch-165, Time-1.1e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003283
# Epoch-166, Time-1.1e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003015
# Epoch-167, Time-1.1e+01, Discriminator_loss-0.25, Generator_loss-0.1249, reconstruction_loss-0.003289
# Epoch-168, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.002807
# Epoch-169, Time-1.1e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003079
# Epoch-170, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.002947
# Epoch-171, Time-1.1e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.002943
# Epoch-172, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.002969
# Epoch-173, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003327
# Epoch-174, Time-1.1e+01, Discriminator_loss-0.25, Generator_loss-0.1251, reconstruction_loss-0.002807
# Epoch-175, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003047
# Epoch-176, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003163
# Epoch-177, Time-1.3e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003202
# Epoch-178, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003139
# Epoch-179, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003312
# Epoch-180, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.1249, reconstruction_loss-0.003023
# Epoch-181, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.1249, reconstruction_loss-0.003298
# Epoch-182, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003059
# Epoch-183, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.1251, reconstruction_loss-0.003029
# Epoch-184, Time-1.2e+01, Discriminator_loss-0.2501, Generator_loss-0.1251, reconstruction_loss-0.003072
# Epoch-185, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003217
# Epoch-186, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003052
# Epoch-187, Time-1.1e+01, Discriminator_loss-0.25, Generator_loss-0.1251, reconstruction_loss-0.003135
# Epoch-188, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003176
# Epoch-189, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.002908
# Epoch-190, Time-1.2e+01, Discriminator_loss-0.2499, Generator_loss-0.1251, reconstruction_loss-0.003452
# Epoch-191, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003075
# Epoch-192, Time-1.2e+01, Discriminator_loss-0.2499, Generator_loss-0.1251, reconstruction_loss-0.003096
# Epoch-193, Time-1.1e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.002984
# Epoch-194, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.002892
# Epoch-195, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.002898
# Epoch-196, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003144
# Epoch-197, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003091
# Epoch-198, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.1251, reconstruction_loss-0.003061
# Epoch-199, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003117
# Epoch-200, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003
# Epoch-201, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003022
# Epoch-202, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003049
# Epoch-203, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003189
# Epoch-204, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003186
# Epoch-205, Time-1.2e+01, Discriminator_loss-0.2499, Generator_loss-0.125, reconstruction_loss-0.002952
# Epoch-206, Time-1.2e+01, Discriminator_loss-0.2499, Generator_loss-0.125, reconstruction_loss-0.003321
# Epoch-207, Time-1.2e+01, Discriminator_loss-0.2499, Generator_loss-0.1256, reconstruction_loss-0.003084
# Epoch-208, Time-1.1e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003064
# Epoch-209, Time-1.1e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003321
# Epoch-210, Time-1.1e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.002963
# Epoch-211, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003153
# Epoch-212, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003072
# Epoch-213, Time-1.3e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.002965
# Epoch-214, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.00283
# Epoch-215, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.002955
# Epoch-216, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003036
# Epoch-217, Time-1.1e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.00283
# Epoch-218, Time-1.1e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003387
# Epoch-219, Time-1.1e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.002985
# Epoch-220, Time-1.1e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003005
# Epoch-221, Time-1.3e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003175
# Epoch-222, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003297
# Epoch-223, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003201
# Epoch-224, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.002926
# Epoch-225, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.0029
# Epoch-226, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003303
# Epoch-227, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003085
# Epoch-228, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003131
# Epoch-229, Time-1.4e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.002973
# Epoch-230, Time-1.4e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003031
# Epoch-231, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003271
# Epoch-232, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003228
# Epoch-233, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003022
# Epoch-234, Time-1.2e+01, Discriminator_loss-0.2498, Generator_loss-0.125, reconstruction_loss-0.003263
# Epoch-235, Time-1.2e+01, Discriminator_loss-0.2501, Generator_loss-0.125, reconstruction_loss-0.003293
# Epoch-236, Time-1.2e+01, Discriminator_loss-0.2502, Generator_loss-0.125, reconstruction_loss-0.002897
# Epoch-237, Time-1.2e+01, Discriminator_loss-0.2501, Generator_loss-0.1249, reconstruction_loss-0.003249
# Epoch-238, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.1249, reconstruction_loss-0.00291
# Epoch-239, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003159
# Epoch-240, Time-1.2e+01, Discriminator_loss-0.2499, Generator_loss-0.125, reconstruction_loss-0.003024
# Epoch-241, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003404
# Epoch-242, Time-1.1e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003264
# Epoch-243, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.002981
# Epoch-244, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003247
# Epoch-245, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.002983
# Epoch-246, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.1249, reconstruction_loss-0.003153
# Epoch-247, Time-1.1e+01, Discriminator_loss-0.25, Generator_loss-0.1249, reconstruction_loss-0.003033
# Epoch-248, Time-1.1e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.00314
# Epoch-249, Time-1.2e+01, Discriminator_loss-0.25, Generator_loss-0.125, reconstruction_loss-0.003249

# %%
file_location_encoder = "7-least-supervised-encoder.pt"
file_location_decoder = "7-least-supervised-decoder.pt"
torch.save(trained_encoder.state_dict(), file_location_encoder)
torch.save(trained_decoder.state_dict(), file_location_decoder)
